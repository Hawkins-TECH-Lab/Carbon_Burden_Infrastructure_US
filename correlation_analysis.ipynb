# %%
import geopandas as gpd
import numpy as np
import os
import pandas as pd

# %%
base_path = '/work/hawkinslab/jfhawkin/SH-BART/data/vulcan/'
file_names = ['vulcan_x_epa_residential_mn_2015','vulcan_x_epa_commercial_mn_2015',
               'vulcan_x_epa_industrial_mn_2015','vulcan_x_epa_onroad_mn_2015',
               'vulcan_x_epa_total_mn_2015']

res_par_file = os.path.join(base_path,'parquet','vulcan_x_epa_residential_mn_2015_climate.parquet')
com_par_file = os.path.join(base_path,'parquet','vulcan_x_epa_commercial_mn_2015_climate.parquet')
ind_par_file = os.path.join(base_path,'parquet','vulcan_x_epa_industrial_mn_2015_climate.parquet')
tran_par_file = os.path.join(base_path,'parquet','vulcan_x_epa_onroad_mn_2015_climate.parquet')
tot_par_file = os.path.join(base_path,'parquet','vulcan_x_epa_total_mn_2015_climate.parquet')

# %%
residential_df = gpd.read_parquet(res_par_file)
commercial_df = gpd.read_parquet(com_par_file)
transport_df = gpd.read_parquet(tran_par_file)

# %% [markdown]
# # By CBG

# %%
cols = ['dn_weighte',
 'p_wrkage',
 'pct_ao0',
 'pct_ao1',
 'pct_ao2p',
 'r_pctlowwa',
 'totemp',
 'totpop',
 'e5_ret',
 'e5_off',
 'e5_ind',
 'e5_svc',
 'e5_ent',
 'e8_ret',
 'e8_off',
 'e8_ind',
 'e8_svc',
 'e8_ent',
 'e8_ed',
 'e8_hlth',
 'e8_pub',
 'e_pctlowwa',
 'd1a',
 'd1b',
 'd1c',
 'd1c5_ret',
 'd1c5_off',
 'd1c5_ind',
 'd1c5_svc',
 'd1c5_ent',
 'd1c8_ret',
 'd1c8_off',
 'd1c8_ind',
 'd1c8_svc',
 'd1c8_ent',
 'd1c8_ed',
 'd1c8_hlth',
 'd1c8_pub',
 'd1d',
 'd2a_jphh',
 'd2b_e5mix',
 'd2b_e5mixa',
 'd2b_e8mix',
 'd2b_e8mixa',
 'd2a_ephhm',
 'd2c_trpmx1',
 'd2c_trpmx2',
 'd2c_tripeq',
 'd2r_jobpop',
 'd2r_wrkemp',
 'd2a_wrkemp',
 'd2c_wremlx',
 'd3a',
 'd3aao',
 'd3amm',
 'd3apo',
 'd3b',
 'd3bao',
 'd3bmm3',
 'd3bmm4',
 'd3bpo3',
 'd3bpo4',
 'd4a',
 'd4b025',
 'd4b050',
 'd4c',
 'd4d',
 'd4e',
 'd5ar',
 'd5ae',
 'd5br',
 'd5be',
 'd5cr',
 'd5cri',
 'd5ce',
 'd5cei',
 'd5dr',
 'd5dri',
 'd5de',
 'd5dei',
 'd2a_ranked',
 'd2b_ranked',
 'd3b_ranked',
 'd4a_ranked',
 'natwalkind',
 'w_p_lowwag',
 'w_p_medwag',
 'w_p_highwa',
 'gasprice',
 'c_r_white',
 'c_r_male',
 'c_r_lowwag',
 'c_r_medwag',
 'c_r_highwa',
 'c_r_drmv',
 'p_highschool',
 'p_owner',
 'avg_hh_size',
 'med_dwelling_age'
]

rows_keep = ['dn_weighte',
 'd1a',
 'd1b',
 'd1c',
 'd1c5_ret',
 'd1c5_off',
 'd1c5_ind',
 'd1c5_svc',
 'd1c5_ent',
 'd1c8_ret',
 'd1c8_off',
 'd1c8_ind',
 'd1c8_svc',
 'd1c8_ent',
 'd1c8_ed',
 'd1c8_hlth',
 'd1c8_pub',
 'd1d',
 'd2a_jphh',
 'd2b_e5mix',
 'd2b_e5mixa',
 'd2b_e8mix',
 'd2b_e8mixa',
 'd2a_ephhm',
 'd2c_trpmx1',
 'd2c_trpmx2',
 'd2c_tripeq',
 'd2r_jobpop',
 'd2r_wrkemp',
 'd2a_wrkemp',
 'd2c_wremlx',
 'd3a',
 'd3aao',
 'd3amm',
 'd3apo',
 'd3b',
 'd3bao',
 'd3bmm3',
 'd3bmm4',
 'd3bpo3',
 'd3bpo4',
 'd4a',
 'd4b025',
 'd4b050',
 'd4c',
 'd4d',
 'd4e',
 'd5ar',
 'd5ae',
 'd5br',
 'd5be',
 'd5cr',
 'd5cri',
 'd5ce',
 'd5cei',
 'd5dr',
 'd5dri',
 'd5de',
 'd5dei',
 'd2a_ranked',
 'd2b_ranked',
 'd3b_ranked',
 'd4a_ranked',
 'natwalkind',
]
cols_keep = ['p_wrkage',
 'pct_ao0',
 'pct_ao1',
 'pct_ao2p',
 'r_pctlowwa',
 'totemp',
 'totpop',
 'e5_ret',
 'e5_off',
 'e5_ind',
 'e5_svc',
 'e5_ent',
 'e8_ret',
 'e8_off',
 'e8_ind',
 'e8_svc',
 'e8_ent',
 'e8_ed',
 'e8_hlth',
 'e8_pub',
 'e_pctlowwa',
 'w_p_lowwag',
 'w_p_medwag',
 'w_p_highwa',
 'gasprice',
 'c_r_white',
 'c_r_male',
 'c_r_lowwag',
 'c_r_medwag',
 'c_r_highwa',
 'c_r_drmv',
 'p_highschool',
 'p_owner',
 'avg_hh_size',
 'med_dwelling_age',
 # 'precip_201401',
 # 'precip_201407',
 # 'min_temp_201401',
 # 'min_temp_201407',
 # 'mean_temp_201401',
 # 'mean_temp_201407',
 # 'max_temp_201401',
 # 'max_temp_201407',
 # 'stc2erta'
]

# %% [markdown]
# ## Transportation

# %%
transport_df[rows_keep] = transport_df.loc[:, rows_keep].replace(0, 1)
transport_df.loc[:,rows_keep] = np.log(transport_df.loc[:,rows_keep])
correlation_table = transport_df.loc[:, cols].corr()
correlation_table = correlation_table.loc[rows_keep, cols_keep]
correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_transport.csv")
print(correlation_table)
# Out:
# /home/hawkinslab/jfhawkin/.conda/envs/pymc_env/lib/python3.11/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 4
#       2 transport_df.loc[:,rows_keep] = np.log(transport_df.loc[:,rows_keep])
#       3 correlation_table = transport_df.loc[:, cols].corr()
# ----> 4 correlation_table = correlation_table.loc[rows_keep, cols_keep]
#       5 correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_transport.csv")
#       6 print(correlation_table)
#
# File ~/.conda/envs/pymc_env/lib/python3.11/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
# ...

# %%
transport_df.loc[:, rows_keep].describe()

# %% [markdown]
# ## Residential

# %%
cols_keep = ['p_wrkage',
 'pct_ao0',
 'pct_ao1',
 'pct_ao2p',
 'r_pctlowwa',
 'totemp',
 'totpop',
 'e5_ret',
 'e5_off',
 'e5_ind',
 'e5_svc',
 'e5_ent',
 'e8_ret',
 'e8_off',
 'e8_ind',
 'e8_svc',
 'e8_ent',
 'e8_ed',
 'e8_hlth',
 'e8_pub',
 'e_pctlowwa',
 'w_p_lowwag',
 'w_p_medwag',
 'w_p_highwa',
 'gasprice',
 'c_r_white',
 'c_r_male',
 'c_r_lowwag',
 'c_r_medwag',
 'c_r_highwa',
 'c_r_drmv',
 'p_highschool',
 'p_owner',
 'avg_hh_size',
 'med_dwelling_age'
]

# %%
residential_df[rows_keep] = residential_df.loc[:, rows_keep].replace(0, 1)
residential_df.loc[:,rows_keep] = np.log(residential_df.loc[:,rows_keep])

correlation_table = residential_df.loc[:, cols].corr()
correlation_table = correlation_table.loc[rows_keep, cols_keep]
correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_res.csv")
print(correlation_table)

# %% [markdown]
# ## Commercial

# %%
commercial_df[rows_keep] = commercial_df.loc[:, rows_keep].replace(0, 1)
commercial_df.loc[:,rows_keep] = np.log(commercial_df.loc[:,rows_keep])

correlation_table = commercial_df.loc[:, cols].corr()
correlation_table = correlation_table.loc[rows_keep, cols_keep]
correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_commerce.csv")
print(correlation_table)

# %% [markdown]
# # By CBSA

# %% [markdown]
# ## Transportation

# %%
transport_df_cbsa = transport_df.groupby('cbsa').agg(aggregation_functions)
correlation_table = transport_df_cbsa.corr()
correlation_table = correlation_table.loc[rows_keep, cols_keep]
correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_transport_cbsa.csv")
print(correlation_table)

# %% [markdown]
# ## Residential

# %%
residential_df_cbsa = residential_df.groupby('cbsa').agg(aggregation_functions)
correlation_table = residential_df_cbsa.corr()
correlation_table = correlation_table.loc[rows_keep, cols_keep]
correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_res_cbsa.csv")
print(correlation_table)

# %% [markdown]
# ## Commercial

# %%
commercial_df_cbsa = commercial_df.groupby('cbsa').agg(aggregation_functions)
correlation_table = commercial_df_cbsa.corr()
correlation_table = correlation_table.loc[rows_keep, cols_keep]
correlation_table.to_csv("/work/hawkinslab/jfhawkin/SH-BART/results/correlation_table_commerce_cbsa.csv")
print(correlation_table)
